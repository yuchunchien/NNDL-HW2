# %% [markdown]
# # ECBM E6040 Homework 2 - Programming Problem

# %%
from hw2b import load_data, LogisticRegression, HiddenLayer, myMLP, test_mlp
import theano
import theano.tensor as T
# Out:
# Using gpu device 0: GRID K520 (CNMeM is disabled, cuDNN Version is too old. Update to v5, was 3007.)

# %% [markdown]
# ### Problem b: Bullet 2: Comparison between _tanh_ and _softmax_

# %% [markdown]
# #### Activation function: softmax

# %% [markdown]
# Parameters on "A_softmax" running test_mlp function:
#   learning_rate=0.01,
#   L1_reg=0.00,
#   L2_reg=0.0001,
#   n_epochs=1000,
#   batch_size=20,
#   n_hidden=250,
#   verbose=Ture,
#   HLAmt=2,   // Hidden layer amount
#   activation=T.nnet.softmax

# %%
A_softmax = test_mlp(n_hidden=250, HLAmt=2, activation=T.nnet.softmax, verbose=True)
print
print ("Test Accuracy rate: %f%%") % (A_softmax)
# Out:
# ... loading data
# ... building the model
# ... training
# epoch 1, minibatch 3296/3296, validation error 81.161202 %
#      epoch 1, minibatch 3296/3296, test error of best model 80.415065 %
# epoch 2, minibatch 3296/3296, validation error 81.161202 %
# epoch 3, minibatch 3296/3296, validation error 81.161202 %
# Optimization complete. Best validation score of 81.161202 % obtained at iteration 3296, with test performance 80.415065 %
#
# Test Accuracy rate: 19.584935%
# The code for file hw2b.py ran for 0.54m

# %% [markdown]
# #### Activation function: tanh

# %% [markdown]
# Parameters on "test_mlp" running test_mlp function:
#   learning_rate=0.01,
#   L1_reg=0.00,
#   L2_reg=0.0001,
#   n_epochs=1000,
#   batch_size=20,
#   n_hidden=250,
#   verbose=Ture,
#   HLAmt=2,   // Hidden layer amount
#   activation=T.tanh

# %%
A_tanh = test_mlp(n_hidden=250, HLAmt=2, activation=T.tanh, verbose=True)
print
print ("Test Accuracy rate: %f%%") % (A_tanh)
# Out:
# ... loading data
# ... building the model
# ... training
# epoch 1, minibatch 3296/3296, validation error 81.038251 %
#      epoch 1, minibatch 3296/3296, test error of best model 80.330515 %
# epoch 2, minibatch 3296/3296, validation error 63.620219 %
#      epoch 2, minibatch 3296/3296, test error of best model 64.177556 %
# epoch 3, minibatch 3296/3296, validation error 49.562842 %
#      epoch 3, minibatch 3296/3296, test error of best model 52.659493 %
# epoch 4, minibatch 3296/3296, validation error 42.185792 %
#      epoch 4, minibatch 3296/3296, test error of best model 45.142198 %
# epoch 5, minibatch 3296/3296, validation error 38.196721 %
#      epoch 5, minibatch 3296/3296, test error of best model 41.010761 %
# epoch 6, minibatch 3296/3296, validation error 35.969945 %
#      epoch 6, minibatch 3296/3296, test error of best model 38.308993 %
# epoch 7, minibatch 3296/3296, validation error 34.071038 %
# ...

# %% [markdown]
# Discussion:
#   Test Accuracy rate when activation functions are "softmax"s: 19.584935%
#   Test Accuracy rate when activation functions are "tanh"s   : 79.377402%
#
#   The maximum epoch of "softmax" is 3 and the maximum epoch of "tanh" is 285.
#   "softmax" ends the iteration much earlier than "tanh".
#   "softmax"s mainly use in the output layer and do classification.
#   When "softmax"s are used in internal hiddenlayers, they make the outputs of the nodes be somewhat dependent on each other.
#   Therefore, "softmax" has worse result than "tanh".

# %% [markdown]
# ### Problem b: Bullet 3: Experiment with the number of hidden layers

# %% [markdown]
# #### "Activation Function" Selection

# %% [markdown]
# Parameters on "A_act_softmax" running test_mlp function:
#   learning_rate=0.01,
#   L1_reg=0.00,
#   L2_reg=0.0001,
#   n_epochs=1000,
#   batch_size=20,
#   n_hidden=500,
#   verbose=Ture,
#   HLAmt=3,   // Hidden layer amount
#   activation=T.nnet.softmax
#
# Parameters on "A_act_tanh" running test_mlp function:
#   learning_rate=0.01,
#   L1_reg=0.00,
#   L2_reg=0.0001,
#   n_epochs=1000,
#   batch_size=20,
#   n_hidden=500,
#   verbose=Ture,
#   HLAmt=3,   // Hidden layer amount
#   activation=T.tanh

# %%
A_act_softmax = test_mlp(n_hidden=500, HLAmt=3, activation=T.nnet.softmax, verbose=True)
A_act_tanh    = test_mlp(n_hidden=500, HLAmt=3, activation=T.tanh, verbose=True)
print
print ("Test Accuracy rate when activation being softmax: %f%%") % (A_act_softmax)
print ("Test Accuracy rate when activation being tanh: %f%%") % (A_act_tanh)
# Out:
# ... loading data
# ... building the model
# ... training
# epoch 1, minibatch 3296/3296, validation error 81.161202 %
#      epoch 1, minibatch 3296/3296, test error of best model 80.415065 %
# epoch 2, minibatch 3296/3296, validation error 81.161202 %
# epoch 3, minibatch 3296/3296, validation error 81.161202 %
# Optimization complete. Best validation score of 81.161202 % obtained at iteration 3296, with test performance 80.415065 %
# ... loading data
# ... building the model
# ... training
# epoch 1, minibatch 3296/3296, validation error 80.095628 %
#      epoch 1, minibatch 3296/3296, test error of best model 79.358186 %
# epoch 2, minibatch 3296/3296, validation error 58.346995 %
#      epoch 2, minibatch 3296/3296, test error of best model 61.156802 %
# epoch 3, minibatch 3296/3296, validation error 44.631148 %
#      epoch 3, minibatch 3296/3296, test error of best model 47.140661 %
# epoch 4, minibatch 3296/3296, validation error 38.046448 %
# ...

# %% [markdown]
# Discussion:
#   Test Accuracy rate when activation function is softmax: 19.584935%
#   Test Accuracy rate when activation function is tanh   : 81.172175%
#
#   Performance of using "tanh" is better than using "softmax".
#   Therefore, I choose "tanh" as activation function.

# %% [markdown]
# #### "Learning Rate" Selection

# %% [markdown]
# Parameters on "A_LR_01" running test_mlp function:
#   learning_rate=0.1,
#   L1_reg=0.00,
#   L2_reg=0.0001,
#   n_epochs=1000,
#   batch_size=20,
#   n_hidden=500,
#   verbose=Ture,
#   HLAmt=3,   // Hidden layer amount
#   activation=T.tanh
#
# Parameters on "A_LR_001" running test_mlp function:
#   learning_rate=0.01,
#   L1_reg=0.00,
#   L2_reg=0.0001,
#   n_epochs=1000,
#   batch_size=20,
#   n_hidden=500,
#   verbose=Ture,
#   HLAmt=3,   // Hidden layer amount
#   activation=T.tanh
#
# Parameters on "A_LR_0001" running test_mlp function:
#   learning_rate=0.001,
#   L1_reg=0.00,
#   L2_reg=0.0001,
#   n_epochs=1000,
#   batch_size=20,
#   n_hidden=500,
#   verbose=Ture,
#   HLAmt=3,   // Hidden layer amount
#   activation=T.tanh

# %%
A_LR_01   = test_mlp(n_hidden=500, HLAmt=3, activation=T.tanh, verbose=True, learning_rate=0.1)
A_LR_001  = A_act_tanh
A_LR_0001 = test_mlp(n_hidden=500, HLAmt=3, activation=T.tanh, verbose=True, learning_rate=0.001)
print
print ("Test Accuracy rate when learning rate being 0.1: %f%%") % (A_LR_01)
print ("Test Accuracy rate when learning rate being 0.01: %f%%") % (A_LR_001)
print ("Test Accuracy rate when learning rate being 0.001: %f%%") % (A_LR_0001)
# Out:
# ... loading data
# ... building the model
# ... training
# epoch 1, minibatch 3296/3296, validation error 55.942623 %
#      epoch 1, minibatch 3296/3296, test error of best model 56.283628 %
# epoch 2, minibatch 3296/3296, validation error 42.527322 %
#      epoch 2, minibatch 3296/3296, test error of best model 44.315911 %
# epoch 3, minibatch 3296/3296, validation error 37.185792 %
#      epoch 3, minibatch 3296/3296, test error of best model 39.531130 %
# epoch 4, minibatch 3296/3296, validation error 33.237705 %
#      epoch 4, minibatch 3296/3296, test error of best model 35.084550 %
# epoch 5, minibatch 3296/3296, validation error 29.549180 %
#      epoch 5, minibatch 3296/3296, test error of best model 30.603382 %
# epoch 6, minibatch 3296/3296, validation error 34.016393 %
# epoch 7, minibatch 3296/3296, validation error 35.355191 %
# epoch 8, minibatch 3296/3296, validation error 32.295082 %
# epoch 9, minibatch 3296/3296, validation error 28.838798 %
# ...

# %% [markdown]
# Discussion:
#   Test Accuracy rate when learning rate is 0.1  : 77.405842%
#   Test Accuracy rate when learning rate is 0.01 : 81.172175%
#   Test Accuracy rate when learning rate is 0.001: 19.488855%
#
#   The test accuracy rate of learning rate being 0.01 is the best among these tests.
#   Therefore, the learning rate is 0.01.

# %% [markdown]
# #### "Number of Neurons in Each Layer" Selection

# %% [markdown]
# Parameters on "A_n_Hidden_400" running test_mlp function:
#   learning_rate=0.01,
#   L1_reg=0.00,
#   L2_reg=0.0001,
#   n_epochs=1000,
#   batch_size=20,
#   n_hidden=400,
#   verbose=Ture,
#   HLAmt=3,   // Hidden layer amount
#   activation=T.tanh
#
# Parameters on "A_n_Hidden_500" running test_mlp function:
#   learning_rate=0.01,
#   L1_reg=0.00,
#   L2_reg=0.0001,
#   n_epochs=1000,
#   batch_size=20,
#   n_hidden=500,
#   verbose=Ture,
#   HLAmt=3,   // Hidden layer amount
#   activation=T.tanh
#
# Parameters on "A_n_Hidden_600" running test_mlp function:
#   learning_rate=0.01,
#   L1_reg=0.00,
#   L2_reg=0.0001,
#   n_epochs=1000,
#   batch_size=20,
#   n_hidden=600,
#   verbose=Ture,
#   HLAmt=3,   // Hidden layer amount
#   activation=T.tanh

# %%
A_n_Hidden_400 = test_mlp(n_hidden=400, HLAmt=3, activation=T.tanh, verbose=True)
A_n_Hidden_500 = A_act_tanh
A_n_Hidden_600 = test_mlp(n_hidden=600, HLAmt=3, activation=T.tanh, verbose=True)
# Out:
# ... loading data
# ... building the model
# ... training
# epoch 1, minibatch 3296/3296, validation error 79.699454 %
#      epoch 1, minibatch 3296/3296, test error of best model 78.927748 %
# epoch 2, minibatch 3296/3296, validation error 56.830601 %
#      epoch 2, minibatch 3296/3296, test error of best model 59.711760 %
# epoch 3, minibatch 3296/3296, validation error 43.825137 %
#      epoch 3, minibatch 3296/3296, test error of best model 47.144504 %
# epoch 4, minibatch 3296/3296, validation error 38.087432 %
#      epoch 4, minibatch 3296/3296, test error of best model 41.879324 %
# epoch 5, minibatch 3296/3296, validation error 34.836066 %
#      epoch 5, minibatch 3296/3296, test error of best model 37.905457 %
# epoch 6, minibatch 3296/3296, validation error 31.571038 %
#      epoch 6, minibatch 3296/3296, test error of best model 34.377402 %
# epoch 7, minibatch 3296/3296, validation error 29.262295 %
# ...

# %%
print ("Test Accuracy rate when n_hidden being 400: %f%%") % (A_n_Hidden_400)
print ("Test Accuracy rate when n_hidden being 500: %f%%") % (A_n_Hidden_500)
print ("Test Accuracy rate when n_hidden being 600: %f%%") % (A_n_Hidden_600)
# Out:
# Test Accuracy rate when n_hidden being 400: 81.648732%
# Test Accuracy rate when n_hidden being 500: 81.172175%
# Test Accuracy rate when n_hidden being 600: 81.544965%

# %% [markdown]
# Discussion:
#   Test Accuracy rate when n_hidden is 400: 81.648732%
#   Test Accuracy rate when n_hidden is 500: 81.172175%
#   Test Accuracy rate when n_hidden is 600: 81.544965%
#
#   The test accuracy rate when n_hidden is 400 is the best.
#   Therefore, I decide that there are 400 neurons in each hidden layer.

# %% [markdown]
# #### Run MLP with Different Numbers of Hidden Layers = {1,3,5,7}

# %% [markdown]
# Parameters on "A_HLAmt_1" running test_mlp function:
#   learning_rate=0.01,
#   L1_reg=0.00,
#   L2_reg=0.0001,
#   n_epochs=400,  //n_epochs become 400 since then
#   batch_size=20,
#   n_hidden=400,
#   verbose=Ture,
#   HLAmt=1,   // Hidden layer amount
#   activation=T.tanh
#
# Parameters on "A_HLAmt_3" running test_mlp function:
#   learning_rate=0.01,
#   L1_reg=0.00,
#   L2_reg=0.0001,
#   n_epochs=400,
#   batch_size=20,
#   n_hidden=400,
#   verbose=Ture,
#   HLAmt=3,   // Hidden layer amount
#   activation=T.tanh
#
# Parameters on "A_HLAmt_5" running test_mlp function:
#   learning_rate=0.01,
#   L1_reg=0.00,
#   L2_reg=0.0001,
#   n_epochs=400,
#   batch_size=20,
#   n_hidden=400,
#   verbose=Ture,
#   HLAmt=5,   // Hidden layer amount
#   activation=T.tanh
#
# Parameters on "A_HLAmt_7" running test_mlp function:
#   learning_rate=0.01,
#   L1_reg=0.00,
#   L2_reg=0.0001,
#   n_epochs=400,
#   batch_size=20,
#   n_hidden=400,
#   verbose=Ture,
#   HLAmt=7,   // Hidden layer amount
#   activation=T.tanh

# %%
A_HLAmt_1 = test_mlp(n_hidden=400, HLAmt=1, activation=T.tanh, verbose=True)
A_HLAmt_3 = test_mlp(n_hidden=400, HLAmt=3, activation=T.tanh, verbose=True)
A_HLAmt_5 = test_mlp(n_hidden=400, HLAmt=5, activation=T.tanh, verbose=True)
A_HLAmt_7 = test_mlp(n_hidden=400, HLAmt=7, activation=T.tanh, verbose=True)
print
print ("Test Accuracy rate when hidden later amount being 1: %f%%") % (A_HLAmt_1)
print ("Test Accuracy rate when hidden later amount being 3: %f%%") % (A_HLAmt_3)
print ("Test Accuracy rate when hidden later amount being 5: %f%%") % (A_HLAmt_5)
print ("Test Accuracy rate when hidden later amount being 7: %f%%") % (A_HLAmt_7)
# Out:
# ... loading data
# ... building the model
# ... training
# epoch 1, minibatch 3296/3296, validation error 80.614754 %
#      epoch 1, minibatch 3296/3296, test error of best model 79.919293 %
# epoch 2, minibatch 3296/3296, validation error 69.521858 %
#      epoch 2, minibatch 3296/3296, test error of best model 69.515757 %
# epoch 3, minibatch 3296/3296, validation error 56.653005 %
#      epoch 3, minibatch 3296/3296, test error of best model 58.174481 %
# epoch 4, minibatch 3296/3296, validation error 47.636612 %
#      epoch 4, minibatch 3296/3296, test error of best model 49.903920 %
# epoch 5, minibatch 3296/3296, validation error 41.407104 %
#      epoch 5, minibatch 3296/3296, test error of best model 44.177556 %
# epoch 6, minibatch 3296/3296, validation error 38.032787 %
#      epoch 6, minibatch 3296/3296, test error of best model 40.933897 %
# epoch 7, minibatch 3296/3296, validation error 35.696721 %
# ...

# %% [markdown]
# Plot the result (reproducing Figure 1)

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np

x = range(1,8,2)
y = [78.420446, 81.610300, 78.005380, 82.209839]
plt.plot(x, y, '-o')
plt.ylim([77.5,82.5])
plt.xlim([0,8])
plt.title("Number of Hidden Layer = {1,3,5,7}")
plt.xlabel("Number of Hidden Layer")
plt.ylabel("Test Accuracy, [%]")
plt.grid()

# %% [markdown]
# Document the choice of parameters, and discuss what you discover.

# %% [markdown]
# Discussion:
#   Test Accuracy rate when hidden layer amount is 1: 78.420446%
#   Test Accuracy rate when hidden layer amount is 3: 81.610300%
#   Test Accuracy rate when hidden layer amount is 5: 78.005380%
#   Test Accuracy rate when hidden layer amount is 7: 82.209839%
#
#   I expect to have better performance when having more hidden layer. However, the performace of having 5 hidden layer is the worst among these tests. Since I choose the learning rate to be 0.01 when the number of hidden layer is 3, maybe 0.01 is not a suitable learning when the number of hidden layer is 5.

# %% [markdown]
# ### Problem b: Bullet 4: Experiment with the number of hidden layers, but fix the total number of neurons

# %% [markdown]
# The amount of hidden neurons is fixed as 840.

# %% [markdown]
# Parameters on "A_HLAmt_1" running test_mlp function:
#   learning_rate=0.01,
#   L1_reg=0.00,
#   L2_reg=0.0001,
#   n_epochs=400,
#   batch_size=20,
#   n_hidden=840,
#   verbose=Ture,
#   HLAmt=1,   // Hidden layer amount
#   activation=T.tanh
#
# Parameters on "A_HLAmt_2" running test_mlp function:
#   learning_rate=0.01,
#   L1_reg=0.00,
#   L2_reg=0.0001,
#   n_epochs=400,
#   batch_size=20,
#   n_hidden=420,
#   verbose=Ture,
#   HLAmt=2,   // Hidden layer amount
#   activation=T.tanh
#
# Parameters on "A_HLAmt_3" running test_mlp function:
#   learning_rate=0.01,
#   L1_reg=0.00,
#   L2_reg=0.0001,
#   n_epochs=400,
#   batch_size=20,
#   n_hidden=280,
#   verbose=Ture,
#   HLAmt=3,   // Hidden layer amount
#   activation=T.tanh
#
# Parameters on "A_HLAmt_4" running test_mlp function:
#   learning_rate=0.01,
#   L1_reg=0.00,
#   L2_reg=0.0001,
#   n_epochs=400,
#   batch_size=20,
#   n_hidden=210,
#   verbose=Ture,
#   HLAmt=4,   // Hidden layer amount
#   activation=T.tanh
#
# Parameters on "A_HLAmt_5" running test_mlp function:
#   learning_rate=0.01,
#   L1_reg=0.00,
#   L2_reg=0.0001,
#   n_epochs=400,
#   batch_size=20,
#   n_hidden=168,
#   verbose=Ture,
#   HLAmt=5,   // Hidden layer amount
#   activation=T.tanh
#
# Parameters on "A_HLAmt_6" running test_mlp function:
#   learning_rate=0.01,
#   L1_reg=0.00,
#   L2_reg=0.0001,
#   n_epochs=400,
#   batch_size=20,
#   n_hidden=140,
#   verbose=Ture,
#   HLAmt=6,   // Hidden layer amount
#   activation=T.tanh

# %%
A_HLAmt_3 = test_mlp(n_hidden=280, HLAmt=3, activation=T.tanh, verbose=True)
print
print ("Test Accuracy rate when hidden layter amount being 3: %f%%") % (A_HLAmt_3)
# Out:
# ... loading data
# ... building the model
# ... training
# epoch 1, minibatch 3296/3296, validation error 80.778689 %
#      epoch 1, minibatch 3296/3296, test error of best model 79.973098 %
# epoch 2, minibatch 3296/3296, validation error 57.377049 %
#      epoch 2, minibatch 3296/3296, test error of best model 59.965411 %
# epoch 3, minibatch 3296/3296, validation error 44.453552 %
#      epoch 3, minibatch 3296/3296, test error of best model 47.190623 %
# epoch 4, minibatch 3296/3296, validation error 38.032787 %
#      epoch 4, minibatch 3296/3296, test error of best model 41.856264 %
# epoch 5, minibatch 3296/3296, validation error 34.890710 %
#      epoch 5, minibatch 3296/3296, test error of best model 37.717141 %
# epoch 6, minibatch 3296/3296, validation error 33.319672 %
#      epoch 6, minibatch 3296/3296, test error of best model 35.203689 %
# epoch 7, minibatch 3296/3296, validation error 31.489071 %
# ...

# %%
A_HLAmt_1 = test_mlp(n_hidden=840, HLAmt=1, activation=T.tanh, verbose=True)
A_HLAmt_2 = test_mlp(n_hidden=420, HLAmt=2, activation=T.tanh, verbose=True)
A_HLAmt_4 = test_mlp(n_hidden=210, HLAmt=4, activation=T.tanh, verbose=True)
A_HLAmt_5 = test_mlp(n_hidden=168, HLAmt=5, activation=T.tanh, verbose=True)
A_HLAmt_6 = test_mlp(n_hidden=140, HLAmt=6, activation=T.tanh, verbose=True)
print
print ("Test Accuracy rate when hidden layter amount being 1: %f%%") % (A_HLAmt_1)
print ("Test Accuracy rate when hidden layter amount being 2: %f%%") % (A_HLAmt_2)
print ("Test Accuracy rate when hidden layter amount being 3: %f%%") % (A_HLAmt_3)
print ("Test Accuracy rate when hidden layter amount being 4: %f%%") % (A_HLAmt_4)
print ("Test Accuracy rate when hidden layter amount being 5: %f%%") % (A_HLAmt_5)
print ("Test Accuracy rate when hidden layter amount being 6: %f%%") % (A_HLAmt_6)
# Out:
# ... loading data
# ... building the model
# ... training
# epoch 1, minibatch 3296/3296, validation error 79.494536 %
#      epoch 1, minibatch 3296/3296, test error of best model 78.900846 %
# epoch 2, minibatch 3296/3296, validation error 71.256831 %
#      epoch 2, minibatch 3296/3296, test error of best model 71.591084 %
# epoch 3, minibatch 3296/3296, validation error 59.275956 %
#      epoch 3, minibatch 3296/3296, test error of best model 60.445811 %
# epoch 4, minibatch 3296/3296, validation error 50.642077 %
#      epoch 4, minibatch 3296/3296, test error of best model 52.697925 %
# epoch 5, minibatch 3296/3296, validation error 43.674863 %
#      epoch 5, minibatch 3296/3296, test error of best model 46.606457 %
# epoch 6, minibatch 3296/3296, validation error 39.918033 %
#      epoch 6, minibatch 3296/3296, test error of best model 42.590315 %
# epoch 7, minibatch 3296/3296, validation error 37.336066 %
# ...

# %% [markdown]
# Plot the result(reproducing Figure 2)

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np

x = range(1,7,1)
y = [A_HLAmt_1, A_HLAmt_2, A_HLAmt_3, A_HLAmt_4, A_HLAmt_5, A_HLAmt_6]
plt.plot(x, y, '-o')
plt.ylim([74.5,82.5])
plt.xlim([0,7])
plt.title("Fixed Amount of Hidden Neurons with Different Number of Hidden Layers")
plt.xlabel("Number of Hidden Layer = {1,2,3,4,5,6}")
plt.ylabel("Test Accuracy, [%]")
plt.grid()

# %% [markdown]
# Document the choice of parameters, and discuss what you discover.

# %% [markdown]
# Discussion:
#   Test Accuracy rate when hidden layter amount being 1: 75.188317%
#   Test Accuracy rate when hidden layter amount being 2: 81.033820%
#   Test Accuracy rate when hidden layter amount being 3: 81.802460%
#   Test Accuracy rate when hidden layter amount being 4: 79.903920%
#   Test Accuracy rate when hidden layter amount being 5: 78.474251%
#   Test Accuracy rate when hidden layter amount being 6: 80.180630%
#
#   Among these tests, the performance of having 3 hidden layers is the best, having same trend in "Figure 2" on the assignment. However, the performance of having 6 hidden layers is better than having 4 and 5 hidden layers. It is different from the trend in "Figure 2" on the assignment.

# %% [markdown]
# ### Problem b: Bullet 5: Experiment with the number of neurons in hidden layers, but fix the number of hidden layers

# %% [markdown]
# Parameters on "A_L1_n_hidden_100" running test_mlp function:
#   learning_rate=0.01,
#   L1_reg=0.00,
#   L2_reg=0.0001,
#   n_epochs=400,
#   batch_size=20,
#   n_hidden=100,
#   verbose=Ture,
#   HLAmt=1,   // Hidden layer amount
#   activation=T.tanh
#
# Parameters on "A_L1_n_hidden_200" running test_mlp function:
#   learning_rate=0.01,
#   L1_reg=0.00,
#   L2_reg=0.0001,
#   n_epochs=400,
#   batch_size=20,
#   n_hidden=200,
#   verbose=Ture,
#   HLAmt=1,   // Hidden layer amount
#   activation=T.tanh
#
# Parameters on "A_L1_n_hidden_300" running test_mlp function:
#   learning_rate=0.01,
#   L1_reg=0.00,
#   L2_reg=0.0001,
#   n_epochs=400,
#   batch_size=20,
#   n_hidden=300,
#   verbose=Ture,
#   HLAmt=1,   // Hidden layer amount
#   activation=T.tanh
#
# Parameters on "A_L1_n_hidden_400" running test_mlp function:
#   learning_rate=0.01,
#   L1_reg=0.00,
#   L2_reg=0.0001,
#   n_epochs=400,
#   batch_size=20,
#   n_hidden=400,
#   verbose=Ture,
#   HLAmt=1,   // Hidden layer amount
#   activation=T.tanh
#
# Parameters on "A_L1_n_hidden_500" running test_mlp function:
#   learning_rate=0.01,
#   L1_reg=0.00,
#   L2_reg=0.0001,
#   n_epochs=400,
#   batch_size=20,
#   n_hidden=500,
#   verbose=Ture,
#   HLAmt=1,   // Hidden layer amount
#   activation=T.tanh
#
# Parameters on "A_L1_n_hidden_600" running test_mlp function:
#   learning_rate=0.01,
#   L1_reg=0.00,
#   L2_reg=0.0001,
#   n_epochs=400,
#   batch_size=20,
#   n_hidden=600,
#   verbose=Ture,
#   HLAmt=1,   // Hidden layer amount
#   activation=T.tanh
#
# Parameters on "A_L1_n_hidden_840" running test_mlp function:
#   learning_rate=0.01,
#   L1_reg=0.00,
#   L2_reg=0.0001,
#   n_epochs=400,
#   batch_size=20,
#   n_hidden=840,
#   verbose=Ture,
#   HLAmt=1,   // Hidden layer amount
#   activation=T.tanh

# %%
A_L1_n_hidden_100 = test_mlp(n_hidden=100, HLAmt=1, activation=T.tanh, verbose=True)
A_L1_n_hidden_200 = test_mlp(n_hidden=200, HLAmt=1, activation=T.tanh, verbose=True)
A_L1_n_hidden_300 = test_mlp(n_hidden=300, HLAmt=1, activation=T.tanh, verbose=True)
A_L1_n_hidden_400 = test_mlp(n_hidden=400, HLAmt=1, activation=T.tanh, verbose=True)
A_L1_n_hidden_500 = test_mlp(n_hidden=500, HLAmt=1, activation=T.tanh, verbose=True)
A_L1_n_hidden_600 = test_mlp(n_hidden=600, HLAmt=1, activation=T.tanh, verbose=True)
A_L1_n_hidden_840 = A_HLAmt_1
print
print ("Test Accuracy rate when n_hidden being 100: %f%%") % (A_L1_n_hidden_100)
print ("Test Accuracy rate when n_hidden being 200: %f%%") % (A_L1_n_hidden_200)
print ("Test Accuracy rate when n_hidden being 300: %f%%") % (A_L1_n_hidden_300)
print ("Test Accuracy rate when n_hidden being 400: %f%%") % (A_L1_n_hidden_400)
print ("Test Accuracy rate when n_hidden being 500: %f%%") % (A_L1_n_hidden_500)
print ("Test Accuracy rate when n_hidden being 600: %f%%") % (A_L1_n_hidden_600)
print ("Test Accuracy rate when n_hidden being 840: %f%%") % (A_L1_n_hidden_840)
# Out:
# ... loading data
# ... building the model
# ... training
# epoch 1, minibatch 3296/3296, validation error 81.161202 %
#      epoch 1, minibatch 3296/3296, test error of best model 80.407379 %
# epoch 2, minibatch 3296/3296, validation error 71.434426 %
#      epoch 2, minibatch 3296/3296, test error of best model 70.810915 %
# epoch 3, minibatch 3296/3296, validation error 58.278689 %
#      epoch 3, minibatch 3296/3296, test error of best model 60.138355 %
# epoch 4, minibatch 3296/3296, validation error 50.969945 %
#      epoch 4, minibatch 3296/3296, test error of best model 52.905457 %
# epoch 5, minibatch 3296/3296, validation error 43.907104 %
#      epoch 5, minibatch 3296/3296, test error of best model 46.936972 %
# epoch 6, minibatch 3296/3296, validation error 39.494536 %
#      epoch 6, minibatch 3296/3296, test error of best model 42.601845 %
# epoch 7, minibatch 3296/3296, validation error 36.898907 %
# ...

# %% [markdown]
# Plot the result (reproducing Figure 3)

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np

x = [100, 200, 300, 400, 500, 600, 840]
y = [A_L1_n_hidden_100, A_L1_n_hidden_200, A_L1_n_hidden_300, A_L1_n_hidden_400, A_L1_n_hidden_500, A_L1_n_hidden_600, A_L1_n_hidden_840]
plt.plot(x, y, '-o')
plt.ylim([74.5,80.5])
plt.xlim([0,900])
plt.title("Fixed Number of Hidden Layers with Different Number of Hidden Neurons")
plt.xlabel("Number of Hidden Neurons = {100, 200, 300, 400, 500, 600, 840}")
plt.ylabel("Test Accuracy, [%]")
plt.grid()

# %% [markdown]
# Document the choice of parameters, and discuss what you discover.

# %% [markdown]
# Discussion:
#   Test Accuracy rate when n_hidden is 100: 75.799385%
#   Test Accuracy rate when n_hidden is 200: 79.581091%
#   Test Accuracy rate when n_hidden is 300: 78.439662%
#   Test Accuracy rate when n_hidden is 400: 78.420446%
#   Test Accuracy rate when n_hidden is 500: 78.235972%
#   Test Accuracy rate when n_hidden is 600: 79.773251%
#   Test Accuracy rate when n_hidden is 840: 75.188317%
#
#   All the tests have only one hidden layer. The performance when having 600 hidden neurons is the best among these tests. The performance when having the most (840) and the least (100) are not as good as others. Thus, the experiments tell me that having more or fewer hidden neurons does not mean better performance.

# %% [markdown]
# ### Problem c: Bullet 1: Implement MLP(with dropout) with the parameters specified

# %%
from hw2c import load_data, LogisticRegression, DropoutHiddenLayer, test_mlp_dropout, drop
import theano
import theano.tensor as T
# Out:
# Using gpu device 0: GRID K520 (CNMeM is disabled, cuDNN Version is too old. Update to v5, was 3007.)

# %%
test_mlp_dropout(learning_rate=0.01, L1_reg=0.0, L2_reg=0.0001, n_epochs=500,
             batch_size=20, n_hidden=500, verbose=True, acttest=T.tanh)
# Out:
# ...
# ... loading data
# ... building the model
# ... training
# epoch 1, minibatch 3296/3296, validation error 81.161202 %
#      epoch 1, minibatch 3296/3296, test error of best model 80.418909 %
# epoch 2, minibatch 3296/3296, validation error 81.051913 %
#      epoch 2, minibatch 3296/3296, test error of best model 80.368947 %
# epoch 3, minibatch 3296/3296, validation error 80.765027 %
#      epoch 3, minibatch 3296/3296, test error of best model 79.992314 %
# epoch 4, minibatch 3296/3296, validation error 76.024590 %
#      epoch 4, minibatch 3296/3296, test error of best model 75.215219 %
# epoch 5, minibatch 3296/3296, validation error 62.855191 %
#      epoch 5, minibatch 3296/3296, test error of best model 64.215988 %
# epoch 6, minibatch 3296/3296, validation error 56.092896 %
#      epoch 6, minibatch 3296/3296, test error of best model 57.386626 %
# epoch 7, minibatch 3296/3296, validation error 50.519126 %
# ...

# %% [markdown]
# Test Accuracy Rate with Dropout (p=0.7): (1 - 0.1473) * 100 % = 85.27%

# %% [markdown]
# ### Problem c: Bullet 2: Implement MLP(without dropout) with the parameters specified

# %%
test_mlp_dropout(learning_rate=0.01, L1_reg=0.0, L2_reg=0.0001, n_epochs=500,
             batch_size=20, n_hidden=500, verbose=True, acttest=T.tanh)
# Out:
# ... loading data
# ... building the model
# ... training
# epoch 1, minibatch 3296/3296, validation error 81.106557 %
#      epoch 1, minibatch 3296/3296, test error of best model 80.330515 %
# epoch 2, minibatch 3296/3296, validation error 73.032787 %
#      epoch 2, minibatch 3296/3296, test error of best model 72.498078 %
# epoch 3, minibatch 3296/3296, validation error 56.953552 %
#      epoch 3, minibatch 3296/3296, test error of best model 57.978478 %
# epoch 4, minibatch 3296/3296, validation error 46.079235 %
#      epoch 4, minibatch 3296/3296, test error of best model 47.413528 %
# epoch 5, minibatch 3296/3296, validation error 40.751366 %
#      epoch 5, minibatch 3296/3296, test error of best model 42.255957 %
# epoch 6, minibatch 3296/3296, validation error 36.243169 %
#      epoch 6, minibatch 3296/3296, test error of best model 38.378171 %
# epoch 7, minibatch 3296/3296, validation error 33.251366 %
# ...

# %% [markdown]
# Test Accuracy Rate without Dropout (p=1): (1 - 0.1929) * 100 % = 80.71%

# %% [markdown]
# ### Problem c: Bullet 2: Compare the two cases

# %% [markdown]
# Discussion:
#   At the beginning of the training part, the MLP without dropout reaches better performance much faster than the MLP with dropout. For example, at epoch 5, test error of best model of the MLP without dropout is 42.26%. However, at epoch 5, test error of best model of the MLP with dropout is 64.22%. Nevertheless, the final test accuracy rate of the MLP with dropout, 85.27% , is better than the MLP without dropout, 80.71%. It is because that the MLP with dropout may not suffer from being overfitting and gets better test accuracy rate.
